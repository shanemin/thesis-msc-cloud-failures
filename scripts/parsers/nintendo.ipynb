# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/nintendo/2020/20206' #subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/nintendo*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    test = soup.find('section', {'class': 'l-container'})
    result.append(test.text.split())
    
    return result

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'rss' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 0.2868175506591797

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
print(res[0])
# Out:
# 751
# ['nintendo', 'global-status', '20200529T080001', ['Provides', 'information', 'about', 'network', 'outages', 'within', 'the', 'last', '24', 'hours.', 'Last', 'update:', 'Date', 'and', 'time', 'to', 'Pacific', 'Time', 'Pacific', 'Time', 'Ongoing', 'Error', 'Code', 'Network', 'Maintenance', 'Information', '/', 'Operational', 'Status']]

# %%
for row in df['status']:
    if row != ['Provides', 'information', 'about', 'network', 'outages', 'within', 'the', 'last', '24', 'hours.', 'Last', 'update:', 'Date', 'and', 'time', 'to', 'Pacific', 'Time', 'Pacific', 'Time', 'Ongoing', 'Error', 'Code', 'Network', 'Maintenance', 'Information', '/', 'Operational', 'Status']:
        print('There is data!')
# There is no data...

# %%
column_names = ['source','service','timestamp_dir','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#       source        service    timestamp_dir  \
# 0   nintendo  global-status  20200529T080001
# 1   nintendo  global-status  20200529T060001
# 2   nintendo  global-status  20200529T090001
# 3   nintendo  global-status  20200529T070001
# 4   nintendo  global-status  20200529T160001
# 5   nintendo  global-status  20200529T170001
# 6   nintendo  global-status  20200529T030001
# 7   nintendo  global-status  20200529T100001
# 8   nintendo  global-status  20200529T190001
# 9   nintendo  global-status  20200529T040002
# 10  nintendo  global-status  20200529T010002
# 11  nintendo  global-status  20200529T110001
# 12  nintendo  global-status  20200529T200001
# 13  nintendo  global-status  20200529T150001
# 14  nintendo  global-status  20200529T120001
# 15  nintendo  global-status  20200529T050001
# 16  nintendo  global-status  20200529T130001
# 17  nintendo  global-status  20200529T210001
# 18  nintendo  global-status  20200529T140001
# 19  nintendo  global-status  20200529T220001
# ...

# %%
# df.to_csv(r'/home/shane/Documents/thesis/output/parsed/nintendo.csv', index=False)
