# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/atlassian' # one directory
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/atlassian/2020/20203' # subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/atlassian*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    timestamp = soup.find('meta', attrs={'name':'issued'}).get('content')
    ts_uct = datetime.utcfromtimestamp(int(timestamp)).strftime('%Y-%m-%d %H:%M:%S')
    
    components = []
    for component in soup.find_all("span", {"class": "name"}):
        s = ' '.join(component.text.split())
        if 'Signup' in s:
            # we don't want commas in component names, for reasons
            s = s.replace('Signup,', 'Signup &')
        components.append(s)

    statuses = []
    for status in soup.find_all("span", {"class": "component-status"}):
        statuses.append(' '.join(status.text.split()))

    for x in range(len(statuses)):
        result.append([components[x], statuses[x]])

    return ts_uct, [result]

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts_dir = item.split('/')[0]
            ts_site, data = extract_html_data(html)
            data.insert(0, ts_site)
            data.insert(0, ts_dir)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)

pool = mp.Pool(mp.cpu_count())

start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 204.4103639125824

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 23864

# %%
column_names = ['source','service','timestamp_dir','timestamp_site','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#        source            service    timestamp_dir       timestamp_site  \
# 0   atlassian         confluence  20200508T150001  2020-05-08 15:00:09
# 1   atlassian      jira-software  20200508T150001  2020-05-08 15:00:08
# 2   atlassian          jira-core  20200508T150001  2020-05-08 15:00:10
# 3   atlassian         jira-align  20200508T150001  2020-05-08 15:00:26
# 4   atlassian          bitbucket  20200508T150001  2020-05-08 14:46:49
# 5   atlassian            support  20200508T150001  2020-05-08 14:00:07
# 6   atlassian         developers  20200508T150001  2020-05-08 14:35:53
# 7   atlassian         statuspage  20200508T150001  2020-05-08 15:00:11
# 8   atlassian             trello  20200508T150001  2020-05-08 14:44:34
# 9   atlassian           partners  20200508T150001  2020-05-08 15:00:21
# 10  atlassian             access  20200508T150001  2020-05-08 15:00:26
# 11  atlassian  jira-service-desk  20200508T150001  2020-05-08 14:00:09
# 12  atlassian           opsgenie  20200508T150001  2020-05-08 14:41:20
# 13  atlassian         confluence  20200508T060001  2020-05-08 06:00:28
# 14  atlassian      jira-software  20200508T060001  2020-05-08 05:00:02
# 15  atlassian          jira-core  20200508T060001  2020-05-08 06:00:28
# 16  atlassian         jira-align  20200508T060001  2020-05-08 06:00:23
# 17  atlassian          bitbucket  20200508T060001  2020-05-08 05:48:01
# 18  atlassian            support  20200508T060001  2020-05-08 06:00:27
# 19  atlassian         developers  20200508T060001  2020-05-08 05:54:11
# 20  atlassian         statuspage  20200508T060001  2020-05-08 06:00:27
# 21  atlassian             trello  20200508T060001  2020-05-08 05:44:02
# 22  atlassian           partners  20200508T060001  2020-05-08 05:00:08
# 23  atlassian             access  20200508T060001  2020-05-08 05:02:54
# 24  atlassian  jira-service-desk  20200508T060001  2020-05-08 05:52:35
# 25  atlassian           opsgenie  20200508T060001  2020-05-08 05:53:20
# 26  atlassian         confluence  20200508T130001  2020-05-08 13:00:27
# 27  atlassian      jira-software  20200508T130001  2020-05-08 13:00:26
# 28  atlassian          jira-core  20200508T130001  2020-05-08 13:00:24
# 29  atlassian         jira-align  20200508T130001  2020-05-08 13:00:23
# 30  atlassian          bitbucket  20200508T130001  2020-05-08 12:48:00
# 31  atlassian            support  20200508T130001  2020-05-08 13:00:22
# 32  atlassian         developers  20200508T130001  2020-05-08 13:00:26
# 33  atlassian         statuspage  20200508T130001  2020-05-08 13:00:28
# 34  atlassian             trello  20200508T130001  2020-05-08 12:56:02
# 35  atlassian           partners  20200508T130001  2020-05-08 12:00:25
# 36  atlassian             access  20200508T130001  2020-05-08 13:00:23
# 37  atlassian  jira-service-desk  20200508T130001  2020-05-08 13:00:28
# 38  atlassian           opsgenie  20200508T130001  2020-05-08 12:51:19
# 39  atlassian         confluence  20200508T200001  2020-05-08 18:55:46
# 40  atlassian      jira-software  20200508T200001  2020-05-08 19:54:09
# 41  atlassian          jira-core  20200508T200001  2020-05-08 18:55:44
# 42  atlassian         jira-align  20200508T200001  2020-05-08 19:56:35
# 43  atlassian          bitbucket  20200508T200001  2020-05-08 19:59:15
# 44  atlassian            support  20200508T200001  2020-05-08 19:55:28
# 45  atlassian         developers  20200508T200001  2020-05-08 19:41:27
# 46  atlassian         statuspage  20200508T200001  2020-05-08 20:00:05
# 47  atlassian             trello  20200508T200001  2020-05-08 19:50:51
# 48  atlassian           partners  20200508T200001  2020-05-08 19:56:37
# 49  atlassian             access  20200508T200001  2020-05-08 20:00:04
#
#                                                status
# 0   [[View Content, Operational], [Create and Edit...
# 1   [[Viewing content, Operational], [Create and e...
# 2   [[Viewing content, Operational], [Create and e...
# 3   [[Pod 1, Operational], [Pod 2, Operational], [...
# 4   [[Website, Operational], [API, Operational], [...
# 5   [[Support Portal, Operational], [Ticketing, Op...
# 6   [[APIs, Operational], [Bitbucket Cloud APIs, O...
# 7   [[Hosted Pages, Operational], [HTTP Pages, Ope...
# 8   [[Trello.com, Operational], [API, Operational]...
# 9   [[Partner Portal, Operational], [Partner Suppo...
# 10  [[Domain Claims, Operational], [SAML-based SSO...
# 11  [[Service Desk Web, Operational], [Service Des...
# 12  [[US, Operational], [Incident Flow, Operationa...
# 13  [[View Content, Operational], [Create and Edit...
# 14  [[Viewing content, Operational], [Create and e...
# 15  [[Viewing content, Operational], [Create and e...
# 16  [[Pod 1, Operational], [Pod 2, Operational], [...
# 17  [[Website, Operational], [API, Operational], [...
# 18  [[Support Portal, Operational], [Ticketing, Op...
# 19  [[APIs, Operational], [Bitbucket Cloud APIs, O...
# 20  [[Hosted Pages, Operational], [HTTP Pages, Ope...
# 21  [[Trello.com, Operational], [API, Operational]...
# 22  [[Partner Portal, Operational], [Partner Suppo...
# 23  [[Domain Claims, Operational], [SAML-based SSO...
# 24  [[Service Desk Web, Operational], [Service Des...
# 25  [[US, Operational], [Incident Flow, Operationa...
# 26  [[View Content, Operational], [Create and Edit...
# 27  [[Viewing content, Operational], [Create and e...
# 28  [[Viewing content, Operational], [Create and e...
# 29  [[Pod 1, Operational], [Pod 2, Operational], [...
# 30  [[Website, Operational], [API, Operational], [...
# 31  [[Support Portal, Operational], [Ticketing, Op...
# 32  [[APIs, Operational], [Bitbucket Cloud APIs, O...
# 33  [[Hosted Pages, Operational], [HTTP Pages, Ope...
# 34  [[Trello.com, Operational], [API, Operational]...
# 35  [[Partner Portal, Operational], [Partner Suppo...
# 36  [[Domain Claims, Operational], [SAML-based SSO...
# 37  [[Service Desk Web, Operational], [Service Des...
# 38  [[US, Operational], [Incident Flow, Operationa...
# 39  [[View Content, Operational], [Create and Edit...
# 40  [[Viewing content, Operational], [Create and e...
# 41  [[Viewing content, Operational], [Create and e...
# 42  [[Pod 1, Operational], [Pod 2, Operational], [...
# 43  [[Website, Operational], [API, Operational], [...
# 44  [[Support Portal, Operational], [Ticketing, Op...
# 45  [[APIs, Operational], [Bitbucket Cloud APIs, O...
# 46  [[Hosted Pages, Operational], [HTTP Pages, Ope...
# 47  [[Trello.com, Operational], [API, Operational]...
# 48  [[Partner Portal, Operational], [Partner Suppo...
# 49  [[Domain Claims, Operational], [SAML-based SSO...

# %%
df.to_csv(r'/home/shane/Documents/thesis/output/parsed/atlassian.csv', index=False)

# %% [markdown]
# ### Blow-Up Status Column

# %%
df2 = pd.read_csv('/home/shane/Documents/thesis/output/parsed/atlassian.csv')
df2.head()
# Out:
#       source        service    timestamp_dir       timestamp_site  \
# 0  atlassian     confluence  20200508T150001  2020-05-08 15:00:09
# 1  atlassian  jira-software  20200508T150001  2020-05-08 15:00:08
# 2  atlassian      jira-core  20200508T150001  2020-05-08 15:00:10
# 3  atlassian     jira-align  20200508T150001  2020-05-08 15:00:26
# 4  atlassian      bitbucket  20200508T150001  2020-05-08 14:46:49
#
#                                               status
# 0  [['View Content', 'Operational'], ['Create and...
# 1  [['Viewing content', 'Operational'], ['Create ...
# 2  [['Viewing content', 'Operational'], ['Create ...
# 3  [['Pod 1', 'Operational'], ['Pod 2', 'Operatio...
# 4  [['Website', 'Operational'], ['API', 'Operatio...

# %%
# Get names of the sub-services
status_types = set()
statuses = set()
for status in df2['status']:
    replaced = status.replace("], [","||").replace('[','').replace(']','').replace("', '", ',').replace("'", '')
    for part in replaced.split('||'):
        status_types.add(part.split(',')[0])
        statuses.add(part.split(',')[1])

# %%
statuses
# Out:
# {'Degraded Performance',
#  'Major Outage',
#  'Operational',
#  'Partial Outage',
#  'Under Maintenance'}

# %%
len(status_types) # new columns
# Out:
# 175

# %%
replaced = []
for status in df2['status']:
    replaced.append(status.replace("], [","||").replace('[','').replace(']','').replace("', '", ',').replace("'", ''))
replaced[0]
# Out:
# 'View Content,Operational||Create and Edit,Operational||Comments,Operational||Authentication and User Management,Operational||Search,Operational||Administration,Operational||Notifications,Operational||Marketplace Apps,Operational||Mobile,Operational||iOS App,Operational||Android App,Operational||Purchasing & Licensing,Operational'

# %%
df3 = pd.DataFrame(replaced)
df3.columns = ['status']
df3.head()
# Out:
#                                               status
# 0  View Content,Operational||Create and Edit,Oper...
# 1  Viewing content,Operational||Create and edit,O...
# 2  Viewing content,Operational||Create and edit,O...
# 3  Pod 1,Operational||Pod 2,Operational||Pod 3,Op...
# 4  Website,Operational||API,Operational||SSH,Oper...

# %%
# New dataframe for the statuses
df_status = pd.DataFrame(columns=status_types)
df_status.head()
# Out:
# Empty DataFrame
# Columns: [Trello.com, Partner Directory, Source downloads, Marketplace, Pod 18, Mobile Notification Delivery, Public Website, Service Desk Web, Confluence Cloud APIs, Pod 19, APIs, Bitbucket Cloud APIs, Pingdom Integration, Logs, Viewing content, US, Page SAML 2.0, Pod 9, SSL Provisioning, System Metrics, Authentication, Create and edit, Atlassian Support, Marketing Site (www.statuspage.io), Pod 11, Voice Notification Delivery, In-product Marketplace and app installation (Cloud), Authenticated API, HipChat, Git via HTTPS, Pod 1, Automation, Partner Support Portal, Mercurial via HTTPS, Configuration REST APIs, Developer documentation, Slack, PagerDuty Webhook, EU, Datadog Integration, Ticketing, Administration, Website, HTTP Pages, Page Access Users, Incoming Integration Flow, API Docs, Artifactory (Maven repository), In-product Marketplace and app installation (Server), App listings, App pricing, Developer service desk, User APIs, SMS Notification Delivery, Incident REST API, Page Google Auth, SAML-based SSO, Pod 6, Heartbeat REST API, Pod 14, SSH, Pod 16, Domain Claims, Reporting APIs and dashboards, Admin Google Auth, Incoming Email Service, HTTPS Pages, iOS App, Status Embed Widget, API Documentation, View Content, Pod 12, Shortlinks, aui-cdn.atlassian.com, Pod 2, Admin User+Pass, Third Party Components, Marketplace Apps, Evaluations and purchases, DNS Validation, JiraOps, Partner Business Center, Pod 3, Email Notification Delivery, Heartbeat Monitoring, Pod 15, Incoming Call Routing, Pingdom Email, Search, Create and Edit, Mobile Application, Purchasing & Licensing, Email delivery, Alert REST API, Public Issues Tracker, Chat Integrations, Alert Flow, New Relic Integration, Private listings, Pod 21, ...]
# Index: []
#
# [0 rows x 175 columns]

# %%
# This is a bit ugly
for row, part in enumerate(df3['status']):
    for d in part.split('||'):
        d2 = d.split(',')
        df_status.at[row, d2[0]] = d2[1]
    if row % 1000 == 0:
        print(row)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000

# %%
df_final = df2.join(df_status)

# %%
df_final.drop(['status'], axis=1, inplace=True)

# %%
df_final
# Out:
#           source            service    timestamp_dir       timestamp_site  \
# 0      atlassian         confluence  20200508T150001  2020-05-08 15:00:09
# 1      atlassian      jira-software  20200508T150001  2020-05-08 15:00:08
# 2      atlassian          jira-core  20200508T150001  2020-05-08 15:00:10
# 3      atlassian         jira-align  20200508T150001  2020-05-08 15:00:26
# 4      atlassian          bitbucket  20200508T150001  2020-05-08 14:46:49
# ...          ...                ...              ...                  ...
# 23859  atlassian             trello  20200604T130001  2020-06-04 12:45:12
# 23860  atlassian           partners  20200604T130001  2020-06-04 12:00:21
# 23861  atlassian             access  20200604T130001  2020-06-04 13:00:07
# 23862  atlassian  jira-service-desk  20200604T130001  2020-06-04 13:00:05
# 23863  atlassian           opsgenie  20200604T130001  2020-06-04 12:46:20
#
#         Trello.com Partner Directory Source downloads  Marketplace  \
# 0              NaN               NaN              NaN          NaN
# 1              NaN               NaN              NaN  Operational
# 2              NaN               NaN              NaN  Operational
# 3              NaN               NaN              NaN          NaN
# 4              NaN               NaN      Operational          NaN
# ...            ...               ...              ...          ...
# 23859  Operational               NaN              NaN          NaN
# 23860          NaN       Operational              NaN          NaN
# 23861          NaN               NaN              NaN          NaN
# 23862          NaN               NaN              NaN          NaN
# 23863          NaN               NaN              NaN          NaN
#
#             Pod 18 Mobile Notification Delivery  ... Support Sites Management  \
# 0              NaN                          NaN  ...           NaN        NaN
# 1              NaN                          NaN  ...           NaN        NaN
# 2              NaN                          NaN  ...           NaN        NaN
# 3      Operational                          NaN  ...           NaN        NaN
# 4              NaN                          NaN  ...           NaN        NaN
# ...            ...                          ...  ...           ...        ...
# 23859          NaN                          NaN  ...           NaN        NaN
# 23860          NaN                          NaN  ...           NaN        NaN
# 23861          NaN                          NaN  ...           NaN        NaN
# 23862          NaN                          NaN  ...           NaN        NaN
# 23863          NaN                  Operational  ...           NaN        NaN
#
#       Category landing pages App submissions Web Portal Jira Cloud APIs  \
# 0                        NaN             NaN        NaN             NaN
# 1                        NaN             NaN        NaN             NaN
# 2                        NaN             NaN        NaN             NaN
# 3                        NaN             NaN        NaN             NaN
# 4                        NaN             NaN        NaN             NaN
# ...                      ...             ...        ...             ...
# 23859                    NaN             NaN        NaN             NaN
# 23860                    NaN             NaN        NaN             NaN
# 23861                    NaN             NaN        NaN             NaN
# 23862                    NaN             NaN        NaN             NaN
# 23863                    NaN             NaN        NaN             NaN
#
#       Vendor Home Page        Pod 4 Reporting & Analytics  \
# 0                  NaN          NaN                   NaN
# 1                  NaN          NaN                   NaN
# 2                  NaN          NaN                   NaN
# 3                  NaN  Operational                   NaN
# 4                  NaN          NaN                   NaN
# ...                ...          ...                   ...
# 23859              NaN          NaN                   NaN
# 23860              NaN          NaN                   NaN
# 23861              NaN          NaN                   NaN
# 23862              NaN          NaN                   NaN
# 23863              NaN          NaN           Operational
#
#       Authentication and User Management
# 0                            Operational
# 1                            Operational
# 2                            Operational
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 23859                                NaN
# 23860                                NaN
# 23861                                NaN
# 23862                        Operational
# 23863                                NaN
#
# [23864 rows x 179 columns]

# %%
df_final.to_csv(r'/home/shane/Documents/thesis/output/parsed/final/atlassian.csv', index=False)
