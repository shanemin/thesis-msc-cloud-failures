# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/downrightnow/2019/201912' #subset of above
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/downrightnow*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    try:
        ts = soup.find('span', {'class': 'timestamp'})
        result.append(' '.join(ts.text.split()))
    except:
        result.append('?')
    
    try:
        status = soup.find('span', {'class': 'status'})
        result.append(' '.join(status.text.split()))
    except:
        result.append('?')
    
    return result

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'rss' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 11.952365398406982

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 11904

# %%
column_names = ['source','service','timestamp_dir','timestamp_site','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#           source      service    timestamp_dir  \
# 0   downrightnow       paypal  20191223T200001
# 1   downrightnow       tumblr  20191223T200001
# 2   downrightnow      youtube  20191223T200001
# 3   downrightnow     linkedin  20191223T200001
# 4   downrightnow      typepad  20191223T200001
# 5   downrightnow     facebook  20191223T200001
# 6   downrightnow      twitter  20191223T200001
# 7   downrightnow        gmail  20191223T200001
# 8   downrightnow  livejournal  20191223T200001
# 9   downrightnow      netflix  20191223T200001
# 10  downrightnow   foursquare  20191223T200001
# 11  downrightnow      blogger  20191223T200001
# 12  downrightnow        skype  20191223T200001
# 13  downrightnow      hotmail  20191223T200001
# 14  downrightnow         ning  20191223T200001
# 15  downrightnow    yahoomail  20191223T200001
# 16  downrightnow       paypal  20191223T030001
# 17  downrightnow       tumblr  20191223T030001
# 18  downrightnow      youtube  20191223T030001
# 19  downrightnow     linkedin  20191223T030001
# 20  downrightnow      typepad  20191223T030001
# 21  downrightnow     facebook  20191223T030001
# 22  downrightnow      twitter  20191223T030001
# 23  downrightnow        gmail  20191223T030001
# 24  downrightnow  livejournal  20191223T030001
# 25  downrightnow      netflix  20191223T030001
# 26  downrightnow   foursquare  20191223T030001
# 27  downrightnow      blogger  20191223T030001
# 28  downrightnow        skype  20191223T030001
# 29  downrightnow      hotmail  20191223T030001
# 30  downrightnow         ning  20191223T030001
# 31  downrightnow    yahoomail  20191223T030001
# 32  downrightnow       paypal  20191223T160001
# 33  downrightnow       tumblr  20191223T160001
# 34  downrightnow      youtube  20191223T160001
# 35  downrightnow     linkedin  20191223T160001
# 36  downrightnow      typepad  20191223T160001
# 37  downrightnow     facebook  20191223T160001
# 38  downrightnow      twitter  20191223T160001
# 39  downrightnow        gmail  20191223T160001
# 40  downrightnow  livejournal  20191223T160001
# 41  downrightnow      netflix  20191223T160001
# 42  downrightnow   foursquare  20191223T160001
# 43  downrightnow      blogger  20191223T160001
# 44  downrightnow        skype  20191223T160001
# 45  downrightnow      hotmail  20191223T160001
# 46  downrightnow         ning  20191223T160001
# 47  downrightnow    yahoomail  20191223T160001
# 48  downrightnow       paypal  20191223T170001
# 49  downrightnow       tumblr  20191223T170001
#
#                          timestamp_site status
# 0    Mon, December 23, 2019 2:58 PM EST     Up
# 1    Mon, December 23, 2019 2:58 PM EST     Up
# 2    Mon, December 23, 2019 2:58 PM EST     Up
# 3    Mon, December 23, 2019 2:58 PM EST     Up
# 4    Mon, December 23, 2019 2:58 PM EST     Up
