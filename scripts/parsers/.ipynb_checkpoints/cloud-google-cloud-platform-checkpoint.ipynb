# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloud-google-cloud-platform' # one directory
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloud-google-cloud-platform/2017/201711' #subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloud-google-cloud-platform*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    regions = []
    
    try:
        for status in soup.find_all('span', {'class':'status'}):
            result.append(' '.join(status.text.split()))
    except:
        result.append('?')
    return [result]

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'json' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
try:
    results = pool.map(read_file, [file for file in files])
except:
    print('Error')
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 2.668071746826172

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 716

# %%
column_names = ['source','service','timestamp','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#                          source           service        timestamp  \
# 0   cloud-google-cloud-platform  status-dashboard  20171121T190001
# 1   cloud-google-cloud-platform  status-dashboard  20171121T180001
# 2   cloud-google-cloud-platform  status-dashboard  20171121T050001
# 3   cloud-google-cloud-platform  status-dashboard  20171121T070001
# 4   cloud-google-cloud-platform  status-dashboard  20171121T150001
# 5   cloud-google-cloud-platform  status-dashboard  20171121T210001
# 6   cloud-google-cloud-platform  status-dashboard  20171121T170001
# 7   cloud-google-cloud-platform  status-dashboard  20171121T040001
# 8   cloud-google-cloud-platform  status-dashboard  20171121T110001
# 9   cloud-google-cloud-platform  status-dashboard  20171121T010001
# 10  cloud-google-cloud-platform  status-dashboard  20171121T000001
# 11  cloud-google-cloud-platform  status-dashboard  20171121T020001
# 12  cloud-google-cloud-platform  status-dashboard  20171121T140001
# ...

# %%
df.to_csv(r'/home/shane/Documents/thesis/output/cloud-google-cloud-platform.csv', index=False)
