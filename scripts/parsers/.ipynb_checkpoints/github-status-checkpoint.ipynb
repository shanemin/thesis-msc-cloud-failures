# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/github-status/2019/20199' #subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/github-status*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    timestamp = soup.find('meta', attrs={'name':'issued'}).get('content')
    ts_uct = datetime.utcfromtimestamp(int(timestamp)).strftime('%Y-%m-%d %H:%M:%S')
    
    try:
        components = []
        for name in soup.find_all('span', {'class':'name'}):
            components.append(' '.join(name.text.split()))
        statuses = []
        for status in soup.find_all('span', {'class':'component-status'}):
            statuses.append(' '.join(status.text.split()))
    except:
        result.append('?')
    
    for x in range(len(statuses)):
        result.append([components[x], statuses[x]])
    
    return ts_uct, [result]

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'history' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts_dir = item.split('/')[0]
            ts_site, data = extract_html_data(html)
            data.insert(0, ts_site)
            data.insert(0, ts_dir)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
try:
    results = pool.map(read_file, [file for file in files])
except:
    print('Error')
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 54.51297163963318

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 9612

# %%
column_names = ['source','service','timestamp_dir','timestamp_site','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#            source        service    timestamp_dir       timestamp_site  \
# 0   github-status  global-status  20200508T150001  2020-05-08 14:54:02
# 1   github-status  global-status  20200508T060001  2020-05-08 05:50:15
# 2   github-status  global-status  20200508T130001  2020-05-08 12:53:22
# 3   github-status  global-status  20200508T200001  2020-05-08 19:50:28
# 4   github-status  global-status  20200508T030001  2020-05-08 02:49:28
# 5   github-status  global-status  20200508T090001  2020-05-08 08:52:07
# 6   github-status  global-status  20200508T180001  2020-05-08 17:49:47
# 7   github-status  global-status  20200508T220001  2020-05-08 21:47:52
# 8   github-status  global-status  20200508T010001  2020-05-08 00:50:50
# 9   github-status  global-status  20200508T000001  2020-05-07 23:57:42
# 10  github-status  global-status  20200508T020001  2020-05-08 01:48:22
# 11  github-status  global-status  20200508T050001  2020-05-08 04:49:53
# 12  github-status  global-status  20200508T140001  2020-05-08 13:53:11
# 13  github-status  global-status  20200508T210001  2020-05-08 20:47:29
# 14  github-status  global-status  20200508T190001  2020-05-08 18:50:20
# 15  github-status  global-status  20200508T080001  2020-05-08 07:54:57
# 16  github-status  global-status  20200508T040001  2020-05-08 03:49:57
# 17  github-status  global-status  20200508T100001  2020-05-08 09:52:22
# 18  github-status  global-status  20200508T230001  2020-05-08 22:48:07
# 19  github-status  global-status  20200508T170002  2020-05-08 16:57:55
# 20  github-status  global-status  20200508T120001  2020-05-08 11:52:46
# 21  github-status  global-status  20200508T070001  2020-05-08 06:50:27
# 22  github-status  global-status  20200508T160001  2020-05-08 15:53:36
# 23  github-status  global-status  20200508T110001  2020-05-08 10:52:40
# 24  github-status  global-status  20200502T030001  2020-05-02 02:52:26
# 25  github-status  global-status  20200502T190001  2020-05-02 18:51:42
# 26  github-status  global-status  20200502T050001  2020-05-02 04:49:58
# 27  github-status  global-status  20200502T160001  2020-05-02 15:51:08
# 28  github-status  global-status  20200502T010001  2020-05-02 00:52:01
# 29  github-status  global-status  20200502T060001  2020-05-02 05:53:10
# 30  github-status  global-status  20200502T150001  2020-05-02 14:51:05
# 31  github-status  global-status  20200502T070001  2020-05-02 06:53:23
# 32  github-status  global-status  20200502T230001  2020-05-02 22:52:47
# 33  github-status  global-status  20200502T170001  2020-05-02 16:51:15
# 34  github-status  global-status  20200502T040001  2020-05-02 03:49:41
# 35  github-status  global-status  20200502T200002  2020-05-02 19:52:06
# 36  github-status  global-status  20200502T180001  2020-05-02 17:51:26
# 37  github-status  global-status  20200502T130001  2020-05-02 12:50:20
# 38  github-status  global-status  20200502T120001  2020-05-02 11:50:15
# 39  github-status  global-status  20200502T020001  2020-05-02 01:52:12
# 40  github-status  global-status  20200502T210001  2020-05-02 20:52:27
# 41  github-status  global-status  20200502T140001  2020-05-02 13:55:26
# 42  github-status  global-status  20200502T080001  2020-05-02 07:54:06
# 43  github-status  global-status  20200502T110001  2020-05-02 10:49:50
# 44  github-status  global-status  20200502T090001  2020-05-02 08:49:26
# 45  github-status  global-status  20200502T220001  2020-05-02 21:52:47
# 46  github-status  global-status  20200502T100001  2020-05-02 09:49:46
# 47  github-status  global-status  20200502T000001  2020-05-01 23:51:48
# 48  github-status  global-status  20200505T020001  2020-05-05 01:58:57
# 49  github-status  global-status  20200505T030002  2020-05-05 02:52:00
#
#                                                status
# 0   [[Git Operations, Operational], [API Requests,...
# 1   [[Git Operations, Operational], [API Requests,...
# 2   [[Git Operations, Operational], [API Requests,...
# 3   [[Git Operations, Operational], [API Requests,...
# 4   [[Git Operations, Operational], [API Requests,...
# 5   [[Git Operations, Operational], [API Requests,...
# 6   [[Git Operations, Operational], [API Requests,...
# 7   [[Git Operations, Operational], [API Requests,...
# 8   [[Git Operations, Operational], [API Requests,...
# 9   [[Git Operations, Operational], [API Requests,...
# 10  [[Git Operations, Operational], [API Requests,...
# 11  [[Git Operations, Operational], [API Requests,...
# 12  [[Git Operations, Operational], [API Requests,...
# 13  [[Git Operations, Operational], [API Requests,...
# 14  [[Git Operations, Operational], [API Requests,...
# 15  [[Git Operations, Operational], [API Requests,...
# 16  [[Git Operations, Operational], [API Requests,...
# 17  [[Git Operations, Operational], [API Requests,...
# 18  [[Git Operations, Operational], [API Requests,...
# 19  [[Git Operations, Operational], [API Requests,...
# 20  [[Git Operations, Operational], [API Requests,...
# 21  [[Git Operations, Operational], [API Requests,...
# 22  [[Git Operations, Operational], [API Requests,...
# 23  [[Git Operations, Operational], [API Requests,...
# 24  [[Git Operations, Operational], [API Requests,...
# 25  [[Git Operations, Operational], [API Requests,...
# 26  [[Git Operations, Operational], [API Requests,...
# 27  [[Git Operations, Operational], [API Requests,...
# 28  [[Git Operations, Operational], [API Requests,...
# 29  [[Git Operations, Operational], [API Requests,...
# 30  [[Git Operations, Operational], [API Requests,...
# 31  [[Git Operations, Operational], [API Requests,...
# 32  [[Git Operations, Operational], [API Requests,...
# 33  [[Git Operations, Operational], [API Requests,...
# 34  [[Git Operations, Operational], [API Requests,...
# 35  [[Git Operations, Operational], [API Requests,...
# 36  [[Git Operations, Operational], [API Requests,...
# 37  [[Git Operations, Operational], [API Requests,...
# 38  [[Git Operations, Operational], [API Requests,...
# 39  [[Git Operations, Operational], [API Requests,...
# 40  [[Git Operations, Operational], [API Requests,...
# 41  [[Git Operations, Operational], [API Requests,...
# 42  [[Git Operations, Operational], [API Requests,...
# 43  [[Git Operations, Operational], [API Requests,...
# 44  [[Git Operations, Operational], [API Requests,...
# 45  [[Git Operations, Operational], [API Requests,...
# 46  [[Git Operations, Operational], [API Requests,...
# 47  [[Git Operations, Operational], [API Requests,...
# 48  [[Git Operations, Operational], [API Requests,...
# 49  [[Git Operations, Operational], [API Requests,...

# %%
df.to_csv(r'/home/shane/Documents/thesis/output/parsed/github-status.csv', index=False)

# %% [markdown]
# ### Blow-Up Status Column

# %%
# df2 = pd.read_csv('/home/shane/Documents/thesis/output/parsed/github-status.csv')
df2 = df.copy()
df2.head()
# Out:
#           source        service    timestamp_dir       timestamp_site  \
# 0  github-status  global-status  20200508T150001  2020-05-08 14:54:02
# 1  github-status  global-status  20200508T060001  2020-05-08 05:50:15
# 2  github-status  global-status  20200508T130001  2020-05-08 12:53:22
# 3  github-status  global-status  20200508T200001  2020-05-08 19:50:28
# 4  github-status  global-status  20200508T030001  2020-05-08 02:49:28
#
#                                               status
# 0  [['Git Operations', 'Operational'], ['API Requ...
# 1  [['Git Operations', 'Operational'], ['API Requ...
# 2  [['Git Operations', 'Operational'], ['API Requ...
# 3  [['Git Operations', 'Operational'], ['API Requ...
# 4  [['Git Operations', 'Operational'], ['API Requ...

# %%
# Get names of the sub-services
status_types = set()
for status in df2['status']:
    replaced = status.replace("], [","||").replace('[','').replace(']','').replace("', '", ',').replace("'", '').replace('Issues, PRs, Projects', 'Issues/PRs/Projects')
    for part in replaced.split('||'):
        status_types.add(part.split(',')[0])

# %%
len(status_types) # new columns
# Out:
# 12

# %%
replaced = []
for status in df2['status']:
    replaced.append(status.replace("], [","||").replace('[','').replace(']','').replace("', '", ',').replace("'", '').replace('Issues, PRs, Projects', 'Issues/PRs/Projects'))
replaced[0]
# Out:
# 'Git Operations,Operational||API Requests,Operational||Webhooks,Operational||Visit www.githubstatus.com for more information,Operational||Issues/PRs/Projects,Operational||GitHub Actions,Operational||GitHub Packages,Operational||GitHub Pages,Operational||Other,Operational'

# %%
df3 = pd.DataFrame(replaced)
df3.columns = ['status']
df3.head()
# Out:
#                                               status
# 0  Git Operations,Operational||API Requests,Opera...
# 1  Git Operations,Operational||API Requests,Opera...
# 2  Git Operations,Operational||API Requests,Opera...
# 3  Git Operations,Operational||API Requests,Opera...
# 4  Git Operations,Operational||API Requests,Opera...

# %%
# New dataframe for the statuses
df_status = pd.DataFrame(columns=status_types)
df_status.head()
# Out:
# Empty DataFrame
# Columns: [Other, Gists, Issues/PRs/Projects, Issues, GitHub Packages, Visit www.githubstatus.com for more information, Webhooks, API Requests, GitHub Pages, Notifications, Git Operations, GitHub Actions]
# Index: []

# %%
# This is a bit ugly
for row, part in enumerate(df3['status']):
    for d in part.split('||'):
        d2 = d.split(',')
        df_status.at[row, d2[0]] = d2[1]
    if row % 1000 == 0:
        print(row)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
df_final = df2.join(df_status)
df_final.drop(['status'], axis=1, inplace=True)

# %%
df_final['service'] = 'github'
df_final
# Out:
#              source service    timestamp_dir       timestamp_site  \
# 0     github-status  github  20200508T150001  2020-05-08 14:54:02
# 1     github-status  github  20200508T060001  2020-05-08 05:50:15
# 2     github-status  github  20200508T130001  2020-05-08 12:53:22
# 3     github-status  github  20200508T200001  2020-05-08 19:50:28
# 4     github-status  github  20200508T030001  2020-05-08 02:49:28
# ...             ...     ...              ...                  ...
# 9607  github-status  github  20190709T220001  2019-07-09 21:56:19
# 9608  github-status  github  20190709T200001  2019-07-09 19:52:46
# 9609  github-status  github  20190709T080001  2019-07-09 07:54:24
# 9610  github-status  github  20190709T050001  2019-07-09 04:47:53
# 9611  github-status  github  20190709T060001  2019-07-09 05:56:26
#
#             Other        Gists Issues/PRs/Projects Issues GitHub Packages  \
# 0     Operational          NaN         Operational    NaN     Operational
# 1     Operational          NaN         Operational    NaN     Operational
# 2     Operational          NaN         Operational    NaN     Operational
# 3     Operational          NaN         Operational    NaN     Operational
# 4     Operational          NaN         Operational    NaN     Operational
# ...           ...          ...                 ...    ...             ...
# 9607          NaN  Operational                 NaN    PRs             NaN
# 9608          NaN  Operational                 NaN    PRs             NaN
# 9609          NaN  Operational                 NaN    PRs             NaN
# 9610          NaN  Operational                 NaN    PRs             NaN
# 9611          NaN  Operational                 NaN    PRs             NaN
#
#      Visit www.githubstatus.com for more information     Webhooks  \
# 0                                        Operational  Operational
# 1                                        Operational  Operational
# 2                                        Operational  Operational
# 3                                        Operational  Operational
# 4                                        Operational  Operational
# ...                                              ...          ...
# 9607                                     Operational          NaN
# 9608                                     Operational          NaN
# 9609                                     Operational          NaN
# 9610                                     Operational          NaN
# 9611                                     Operational          NaN
#
#      API Requests GitHub Pages Notifications Git Operations GitHub Actions
# 0     Operational  Operational           NaN    Operational    Operational
# 1     Operational  Operational           NaN    Operational    Operational
# 2     Operational  Operational           NaN    Operational    Operational
# 3     Operational  Operational           NaN    Operational    Operational
# 4     Operational  Operational           NaN    Operational    Operational
# ...           ...          ...           ...            ...            ...
# 9607  Operational  Operational   Operational    Operational            NaN
# 9608  Operational  Operational   Operational    Operational            NaN
# 9609  Operational  Operational   Operational    Operational            NaN
# 9610  Operational  Operational   Operational    Operational            NaN
# 9611  Operational  Operational   Operational    Operational            NaN
#
# [9612 rows x 16 columns]

# %%
df_final.to_csv(r'/home/shane/Documents/thesis/output/parsed/final/github-status.csv', index=False)
