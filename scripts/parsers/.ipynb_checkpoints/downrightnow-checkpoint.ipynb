# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/downrightnow/2019/201912' #subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/downrightnow*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    try:
        ts = soup.find('span', {'class': 'timestamp'})
        result.append(' '.join(ts.text.split()))
    except:
        result.append('?')
    
    try:
        status = soup.find('span', {'class': 'status'})
        result.append(' '.join(status.text.split()))
    except:
        result.append('?')
    
    return result

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'rss' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 388.36804151535034

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 357900

# %%
column_names = ['source','service','timestamp_dir','timestamp_site','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#           source      service    timestamp_dir                 timestamp_site  \
# 0   downrightnow       paypal  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 1   downrightnow       tumblr  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 2   downrightnow      youtube  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 3   downrightnow     linkedin  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 4   downrightnow      typepad  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 5   downrightnow     facebook  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 6   downrightnow      twitter  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 7   downrightnow        gmail  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 8   downrightnow  livejournal  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 9   downrightnow      netflix  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 10  downrightnow   foursquare  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 11  downrightnow      blogger  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 12  downrightnow        skype  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 13  downrightnow      hotmail  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 14  downrightnow         ning  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 15  downrightnow    yahoomail  20200508T150001  Fri, May 8, 2020 10:58 AM EDT
# 16  downrightnow       paypal  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 17  downrightnow       tumblr  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 18  downrightnow      youtube  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 19  downrightnow     linkedin  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 20  downrightnow      typepad  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 21  downrightnow     facebook  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 22  downrightnow      twitter  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 23  downrightnow        gmail  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 24  downrightnow  livejournal  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 25  downrightnow      netflix  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 26  downrightnow   foursquare  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 27  downrightnow      blogger  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 28  downrightnow        skype  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 29  downrightnow      hotmail  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 30  downrightnow         ning  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 31  downrightnow    yahoomail  20200508T060001   Fri, May 8, 2020 1:58 AM EDT
# 32  downrightnow       paypal  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 33  downrightnow       tumblr  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 34  downrightnow      youtube  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 35  downrightnow     linkedin  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 36  downrightnow      typepad  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 37  downrightnow     facebook  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 38  downrightnow      twitter  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 39  downrightnow        gmail  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 40  downrightnow  livejournal  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 41  downrightnow      netflix  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 42  downrightnow   foursquare  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 43  downrightnow      blogger  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 44  downrightnow        skype  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 45  downrightnow      hotmail  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 46  downrightnow         ning  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 47  downrightnow    yahoomail  20200508T130001   Fri, May 8, 2020 8:58 AM EDT
# 48  downrightnow       paypal  20200508T200001   Fri, May 8, 2020 3:58 PM EDT
# 49  downrightnow       tumblr  20200508T200001   Fri, May 8, 2020 3:58 PM EDT
#
#    status
# 0      Up
# 1      Up
# 2      Up
# 3      Up
# 4      Up
# 5      Up
# 6      Up
# 7      Up
# 8      Up
# 9      Up
# 10     Up
# 11     Up
# 12     Up
# 13     Up
# 14     Up
# 15     Up
# 16     Up
# 17     Up
# 18     Up
# 19     Up
# 20     Up
# 21     Up
# 22     Up
# 23     Up
# 24     Up
# 25     Up
# 26     Up
# 27     Up
# 28     Up
# 29     Up
# 30     Up
# 31     Up
# 32     Up
# 33     Up
# 34     Up
# 35     Up
# 36     Up
# 37     Up
# 38     Up
# 39     Up
# 40     Up
# 41     Up
# 42     Up
# 43     Up
# 44     Up
# 45     Up
# 46     Up
# 47     Up
# 48     Up
# 49     Up

# %%
df[df['status'] == '?'].count()
# Out:
# source            82
# service           82
# timestamp_dir     82
# timestamp_site    82
# status            82
# dtype: int64

# %%
df[df['status'] != 'Up'].count()
# Out:
# source            15192
# service           15192
# timestamp_dir     15192
# timestamp_site    15192
# status            15192
# dtype: int64

# %%
df.to_csv(r'/home/shane/Documents/thesis/output/parsed/final/downrightnow.csv', index=False)
