# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/outage.report/2019/20194' #subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/outage.report*' # all directories

# %% [markdown]
# #### Excuse the dirtiness...

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    try:
        ts_site = soup.find('span', {'class':'ServicePage__TimeZoneWrap-l00bv6-0 dPxUZH'})
        result.append(' '.join(ts_site.text.split()))
    except:
        result.append('?')
    
    try:
        gauge_count = soup.find('text', {'class':'Gauge__Count-s1qahqgd-5 gzhUJh'})
        result.append(' '.join(gauge_count.text.split()))
    except:
        result.append('?')
    
    try:
        section = soup.find('section', {'class':'OverlayLoader__Wrap-yneds0-0 hEfbHu'})
        div = section.find('div', {'class':'sc-bdVaJa frYeKI'})
        report_stats = ' '.join(div.text.split())
    except:
        # assume the tag does not always exist...
        report_stats = '0'
        
    # number of countries reporting problems
    # the site html was updated at some point, so we need to check this
    count = 0
    try:
        # here the countries are listed separately
        x = soup.find('span', {'data-message':'CNS'})
        y = x.find('ul', {'class':'DominantMessage2__CommaList-s109d9sz-0 harauJ'})
        count = len(y.find_all('li'))
    except:
        # otherwise its all in one text
        # e.g. Received 4940 reports, originating from Malaysia, United Kingdom, Singapore, Spain, United States and 111 more countries
        count = len(report_stats.split(',')) - 1
    
    # first digit is #reports in 24hrs
    # second digit (if present) is #additional countries reporting problems
    for s in report_stats.split():
        if s.isdigit():
            result.append(s)
    if len(result) != 4:
        result.append(0)
    result[-1] = int(result[-1]) + count
    
    outage_causes = []
    try:
        ul = soup.find('ul', {'class':'OutageSubjectsList__Ul-s10w08k0-0 jfDAxG'})
        for li in ul.find_all('li'):
            outage_causes.append(li.get_text())
    except:
        pass
    result.append(outage_causes)
    
    return result

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'overview' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 15.659606456756592

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 4066

# %%
column_names = ['source','service','timestamp_dir','timezone','reports_20mins','reports_24hrs','reports_countries24hrs','causes']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#            source             service    timestamp_dir          timezone  \
# 0   outage.report             youtube  20190430T110001  EDT (GMT -04:00)
# 1   outage.report            facebook  20190430T110001  EDT (GMT -04:00)
# 2   outage.report             twitter  20190430T110001  EDT (GMT -04:00)
# 3   outage.report               gmail  20190430T110001  EDT (GMT -04:00)
# 4   outage.report             netflix  20190430T110001  EDT (GMT -04:00)
# 5   outage.report  facebook-messenger  20190430T110001  EDT (GMT -04:00)
# 6   outage.report            whatsapp  20190430T110001  EDT (GMT -04:00)
# 7   outage.report               skype  20190430T110001  EDT (GMT -04:00)
# 8   outage.report           instagram  20190430T110001  EDT (GMT -04:00)
# 9   outage.report            snapchat  20190430T110001  EDT (GMT -04:00)
# 10  outage.report             youtube  20190430T200001  EDT (GMT -04:00)
# 11  outage.report            facebook  20190430T200001  EDT (GMT -04:00)
# 12  outage.report             twitter  20190430T200001  EDT (GMT -04:00)
# 13  outage.report               gmail  20190430T200001  EDT (GMT -04:00)
# 14  outage.report             netflix  20190430T200001  EDT (GMT -04:00)
# 15  outage.report  facebook-messenger  20190430T200001  EDT (GMT -04:00)
# 16  outage.report            whatsapp  20190430T200001  EDT (GMT -04:00)
# 17  outage.report               skype  20190430T200001  EDT (GMT -04:00)
# 18  outage.report           instagram  20190430T200001  EDT (GMT -04:00)
# 19  outage.report            snapchat  20190430T200001  EDT (GMT -04:00)
# 20  outage.report             youtube  20190430T060001  EDT (GMT -04:00)
# 21  outage.report            facebook  20190430T060001  EDT (GMT -04:00)
# 22  outage.report             twitter  20190430T060001  EDT (GMT -04:00)
# 23  outage.report               gmail  20190430T060001  EDT (GMT -04:00)
# 24  outage.report             netflix  20190430T060001  EDT (GMT -04:00)
# 25  outage.report  facebook-messenger  20190430T060001  EDT (GMT -04:00)
# 26  outage.report            whatsapp  20190430T060001  EDT (GMT -04:00)
# 27  outage.report               skype  20190430T060001  EDT (GMT -04:00)
# 28  outage.report           instagram  20190430T060001  EDT (GMT -04:00)
# 29  outage.report            snapchat  20190430T060001  EDT (GMT -04:00)
# 30  outage.report             youtube  20190430T170001  EDT (GMT -04:00)
# 31  outage.report            facebook  20190430T170001  EDT (GMT -04:00)
# 32  outage.report             twitter  20190430T170001  EDT (GMT -04:00)
# 33  outage.report               gmail  20190430T170001  EDT (GMT -04:00)
# 34  outage.report             netflix  20190430T170001  EDT (GMT -04:00)
# 35  outage.report  facebook-messenger  20190430T170001  EDT (GMT -04:00)
# 36  outage.report            whatsapp  20190430T170001  EDT (GMT -04:00)
# 37  outage.report               skype  20190430T170001  EDT (GMT -04:00)
# 38  outage.report           instagram  20190430T170001  EDT (GMT -04:00)
# 39  outage.report            snapchat  20190430T170001  EDT (GMT -04:00)
# 40  outage.report             youtube  20190430T090001  EDT (GMT -04:00)
# 41  outage.report            facebook  20190430T090001  EDT (GMT -04:00)
# 42  outage.report             twitter  20190430T090001  EDT (GMT -04:00)
# 43  outage.report               gmail  20190430T090001  EDT (GMT -04:00)
# 44  outage.report             netflix  20190430T090001  EDT (GMT -04:00)
# 45  outage.report  facebook-messenger  20190430T090001  EDT (GMT -04:00)
# 46  outage.report            whatsapp  20190430T090001  EDT (GMT -04:00)
# 47  outage.report               skype  20190430T090001  EDT (GMT -04:00)
# 48  outage.report           instagram  20190430T090001  EDT (GMT -04:00)
# 49  outage.report            snapchat  20190430T090001  EDT (GMT -04:00)
#
#    reports_20mins reports_24hrs  reports_countries24hrs  \
# 0               0            22                      14
# 1               2           223                      35
# 2               0            21                      11
# 3               0            43                      17
# 4               0            28                      11
# 5               0             9                       5
# 6               1            35                      14
# 7               0             6                       4
# 8               1            82                      21
# 9               0            14                       5
# 10              0            34                      17
# 11              3           303                      35
# 12              4            33                      14
# 13              1            42                      19
# 14              1            38                      12
# 15              0             7                       4
# 16              1            33                      15
# 17              0             4                       1
# 18              1            74                      23
# 19              2            16                       8
# 20              0            20                      12
# 21              6           173                      28
# 22              0            15                       8
# 23              0            39                      15
# 24              0            27                      10
# 25              0             9                       5
# 26              2            26                      12
# 27              1             7                       4
# 28              2            71                      18
# 29              0            16                       5
# 30              0            29                      15
# 31              5           283                      37
# 32              0            25                      14
# 33              0            48                      19
# 34              1            35                      13
# 35              1             8                       4
# 36              0            34                      16
# 37              0             4                       1
# 38              0            76                      24
# 39              0            10                       5
# 40              0            19                      12
# 41              2           204                      33
# 42              0            17                       9
# 43              0            44                      16
# 44              0            27                      10
# 45              0             9                       5
# 46              0            27                      12
# 47              0             7                       4
# 48              1            79                      20
# 49              0            13                       5
#
#                                                causes
# 0   [Mobile app not working - 36%, Website down - ...
# 1   [Mobile app not working - 45%, Mobile app cras...
# 2   [Mobile app not working - 55%, Website down - ...
# 3   [Email down - 63%, Website down - 13%, Email r...
# 4   [Stream not working - 58%, Everything is down ...
# 5   [Message read problems - 50%, Message send pro...
# 6   [Message send problems - 43%, Mobile app not w...
# 7   [Message send problems - 33%, Everything is do...
# 8   [Mobile app not working - 49%, Can't upload pi...
# 9   [Mobile app crashes - 40%, Can't login - 20%, ...
# 10  [Videos won't play - 40%, Website down - 30%, ...
# 11  [Mobile app crashes - 45%, Mobile app not work...
# 12  [Mobile app not working - 50%, Website down - ...
# 13  [Website down - 36%, Email down - 23%, Can't l...
# 14  [Stream not working - 39%, Can't login - 22%, ...
# 15  [Mobile app not working - 33%, Message read pr...
# 16  [Message send problems - 42%, Message read pro...
# 17                                                 []
# 18  [Mobile app not working - 30%, Can't login - 2...
# 19  [Can't login - 73%, Mobile app not working - 27%]
# 20  [Mobile app not working - 33%, Videos won't pl...
# 21  [Mobile app not working - 40%, Mobile app cras...
# 22  [Mobile app not working - 50%, Website down - ...
# 23  [Email down - 50%, Website down - 25%, Email r...
# 24  [Stream not working - 52%, Everything is down ...
# 25  [Message read problems - 50%, Message send pro...
# 26  [Message send problems - 58%, Mobile app not w...
# 27  [Mobile app not working - 25%, Message send pr...
# 28  [Mobile app not working - 35%, Can't upload pi...
# 29  [Mobile app crashes - 25%, Everything is down ...
# 30  [Website down - 36%, Videos won't play - 29%, ...
# 31  [Mobile app crashes - 45%, Mobile app not work...
# 32  [Website down - 50%, Mobile app not working - ...
# 33  [Email down - 35%, Website down - 30%, Can't l...
# 34  [Stream not working - 42%, Can't login - 25%, ...
# 35  [Mobile app not working - 50%, Message read pr...
# 36  [Message send problems - 48%, Mobile app not w...
# 37                        [Everything is down - 100%]
# 38  [Mobile app not working - 48%, Can't upload pi...
# 39  [Can't login - 33%, Mobile app not working - 3...
# 40  [Mobile app not working - 33%, Videos won't pl...
# 41  [Mobile app not working - 45%, Mobile app cras...
# 42  [Mobile app not working - 60%, Website down - ...
# 43  [Email down - 67%, Website down - 10%, Email r...
# 44  [Stream not working - 58%, Website down - 11%,...
# 45  [Message read problems - 50%, Mobile app not w...
# 46  [Message send problems - 44%, Message read pro...
# 47  [Mobile app not working - 25%, Message send pr...
# 48  [Mobile app not working - 41%, Can't login - 1...
# 49  [Mobile app crashes - 40%, Can't login - 20%, ...

# %%
df.to_csv(r'/home/shane/Documents/thesis/output/parsed/outage-report.csv', index=False)
