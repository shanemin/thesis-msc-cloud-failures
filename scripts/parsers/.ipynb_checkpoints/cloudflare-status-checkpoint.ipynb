# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloudflare-status' # one directory
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloudflare-status/2019/20196' # subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloudflare-status*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    try:
        for status in soup.find_all('div', {'class': 'component-inner-container'}):
            region = ' '.join(status.find('span').text.split())
            result.append([region, status['data-component-status']])
    except:
        result.append('?')

    return [result]

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'history' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 1.7529051303863525

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 129

# %%
column_names = ['source','service','timestamp','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#                source        service        timestamp  \
# 0   cloudflare-status  global-status  20190630T210001
# 1   cloudflare-status  global-status  20190630T140001
# 2   cloudflare-status  global-status  20190630T060001
# 3   cloudflare-status  global-status  20190630T130001
# 4   cloudflare-status  global-status  20190630T080001
# 5   cloudflare-status  global-status  20190630T040001
# 6   cloudflare-status  global-status  20190630T110001
# 7   cloudflare-status  global-status  20190630T100001
# 8   cloudflare-status  global-status  20190630T190001
# 9   cloudflare-status  global-status  20190630T180001
# 10  cloudflare-status  global-status  20190630T220001
# 11  cloudflare-status  global-status  20190630T200001
# 12  cloudflare-status  global-status  20190630T170001
# 13  cloudflare-status  global-status  20190630T070001
# 14  cloudflare-status  global-status  20190630T150001
# 15  cloudflare-status  global-status  20190630T050001
# 16  cloudflare-status  global-status  20190630T010001
# 17  cloudflare-status  global-status  20190630T120001
# 18  cloudflare-status  global-status  20190630T020001
# 19  cloudflare-status  global-status  20190630T090002
# 20  cloudflare-status  global-status  20190630T230001
# 21  cloudflare-status  global-status  20190630T030001
# 22  cloudflare-status  global-status  20190630T000001
# 23  cloudflare-status  global-status  20190630T160001
# 24  cloudflare-status  global-status  20190625T170001
# 25  cloudflare-status  global-status  20190625T180001
# 26  cloudflare-status  global-status  20190625T220001
# 27  cloudflare-status  global-status  20190625T190002
# 28  cloudflare-status  global-status  20190625T160001
# 29  cloudflare-status  global-status  20190625T200001
# 30  cloudflare-status  global-status  20190625T230001
# 31  cloudflare-status  global-status  20190625T210001
# 32  cloudflare-status  global-status  20190625T150001
# 33  cloudflare-status  global-status  20190627T180001
# 34  cloudflare-status  global-status  20190627T060001
# 35  cloudflare-status  global-status  20190627T120001
# 36  cloudflare-status  global-status  20190627T090001
# 37  cloudflare-status  global-status  20190627T000001
# 38  cloudflare-status  global-status  20190627T230001
# 39  cloudflare-status  global-status  20190627T200001
# 40  cloudflare-status  global-status  20190627T190001
# 41  cloudflare-status  global-status  20190627T080001
# 42  cloudflare-status  global-status  20190627T130001
# 43  cloudflare-status  global-status  20190627T150001
# 44  cloudflare-status  global-status  20190627T220001
# 45  cloudflare-status  global-status  20190627T160001
# 46  cloudflare-status  global-status  20190627T100001
# 47  cloudflare-status  global-status  20190627T050001
# 48  cloudflare-status  global-status  20190627T030001
# 49  cloudflare-status  global-status  20190627T110001
#
#                                                status
# 0   [[Europe, operational], [Amsterdam, Netherland...
# 1   [[Europe, operational], [Amsterdam, Netherland...
