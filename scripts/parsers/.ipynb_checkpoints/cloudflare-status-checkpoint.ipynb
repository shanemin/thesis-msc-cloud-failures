# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloudflare-status' # one directory
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloudflare-status/2019/20196' # subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloudflare-status*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    
    try:
        for status in soup.find_all('div', {'class': 'component-inner-container'}):
            region = ' '.join(status.find('span').text.split())
            result.append([region, status['data-component-status']])
    except:
        result.append('?')

    return [result]

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'history' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
results = pool.map(read_file, [file for file in files])
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 82.35500311851501

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 8433

# %%
column_names = ['source','service','timestamp','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#                source        service        timestamp  \
# 0   cloudflare-status  global-status  20200508T150001
# 1   cloudflare-status  global-status  20200508T060001
# 2   cloudflare-status  global-status  20200508T130001
# 3   cloudflare-status  global-status  20200508T200001
# 4   cloudflare-status  global-status  20200508T030001
# 5   cloudflare-status  global-status  20200508T090001
# 6   cloudflare-status  global-status  20200508T180001
# 7   cloudflare-status  global-status  20200508T220001
# 8   cloudflare-status  global-status  20200508T010001
# 9   cloudflare-status  global-status  20200508T000001
# 10  cloudflare-status  global-status  20200508T020001
# 11  cloudflare-status  global-status  20200508T050001
# 12  cloudflare-status  global-status  20200508T140001
# 13  cloudflare-status  global-status  20200508T210001
# 14  cloudflare-status  global-status  20200508T190001
# 15  cloudflare-status  global-status  20200508T080001
# 16  cloudflare-status  global-status  20200508T040001
# 17  cloudflare-status  global-status  20200508T100001
# 18  cloudflare-status  global-status  20200508T230001
# 19  cloudflare-status  global-status  20200508T170002
# 20  cloudflare-status  global-status  20200508T120001
# 21  cloudflare-status  global-status  20200508T070001
# 22  cloudflare-status  global-status  20200508T160001
# 23  cloudflare-status  global-status  20200508T110001
# 24  cloudflare-status  global-status  20200502T030001
# 25  cloudflare-status  global-status  20200502T190001
# 26  cloudflare-status  global-status  20200502T050001
# 27  cloudflare-status  global-status  20200502T160001
# 28  cloudflare-status  global-status  20200502T010001
# 29  cloudflare-status  global-status  20200502T060001
# 30  cloudflare-status  global-status  20200502T150001
# 31  cloudflare-status  global-status  20200502T070001
# 32  cloudflare-status  global-status  20200502T230001
# 33  cloudflare-status  global-status  20200502T170001
# 34  cloudflare-status  global-status  20200502T040001
# 35  cloudflare-status  global-status  20200502T200002
# 36  cloudflare-status  global-status  20200502T180001
# 37  cloudflare-status  global-status  20200502T130001
# 38  cloudflare-status  global-status  20200502T120001
# 39  cloudflare-status  global-status  20200502T020001
# 40  cloudflare-status  global-status  20200502T210001
# 41  cloudflare-status  global-status  20200502T140001
# 42  cloudflare-status  global-status  20200502T080001
# 43  cloudflare-status  global-status  20200502T110001
# 44  cloudflare-status  global-status  20200502T090001
# 45  cloudflare-status  global-status  20200502T220001
# 46  cloudflare-status  global-status  20200502T100001
# 47  cloudflare-status  global-status  20200502T000001
# 48  cloudflare-status  global-status  20200505T020001
# 49  cloudflare-status  global-status  20200505T030002
#
#                                                status
# 0   [[Cloudflare Sites and Services, operational],...
# 1   [[Cloudflare Sites and Services, operational],...
# 2   [[Cloudflare Sites and Services, operational],...
# 3   [[Cloudflare Sites and Services, operational],...
# 4   [[Cloudflare Sites and Services, operational],...
# 5   [[Cloudflare Sites and Services, operational],...
# 6   [[Cloudflare Sites and Services, operational],...
# 7   [[Cloudflare Sites and Services, operational],...
# 8   [[Cloudflare Sites and Services, operational],...
# 9   [[Cloudflare Sites and Services, operational],...
# 10  [[Cloudflare Sites and Services, operational],...
# 11  [[Cloudflare Sites and Services, operational],...
# 12  [[Cloudflare Sites and Services, operational],...
# 13  [[Cloudflare Sites and Services, operational],...
# 14  [[Cloudflare Sites and Services, operational],...
# 15  [[Cloudflare Sites and Services, operational],...
# 16  [[Cloudflare Sites and Services, operational],...
# 17  [[Cloudflare Sites and Services, operational],...
# 18  [[Cloudflare Sites and Services, operational],...
# 19  [[Cloudflare Sites and Services, operational],...
# 20  [[Cloudflare Sites and Services, operational],...
# 21  [[Cloudflare Sites and Services, operational],...
# 22  [[Cloudflare Sites and Services, operational],...
# 23  [[Cloudflare Sites and Services, operational],...
# 24  [[Cloudflare Sites and Services, operational],...
# 25  [[Cloudflare Sites and Services, operational],...
# 26  [[Cloudflare Sites and Services, operational],...
# 27  [[Cloudflare Sites and Services, operational],...
# 28  [[Cloudflare Sites and Services, operational],...
# 29  [[Cloudflare Sites and Services, operational],...
# 30  [[Cloudflare Sites and Services, operational],...
# 31  [[Cloudflare Sites and Services, operational],...
# 32  [[Cloudflare Sites and Services, operational],...
# 33  [[Cloudflare Sites and Services, operational],...
# 34  [[Cloudflare Sites and Services, operational],...
# 35  [[Cloudflare Sites and Services, operational],...
# 36  [[Cloudflare Sites and Services, operational],...
# 37  [[Cloudflare Sites and Services, operational],...
# 38  [[Cloudflare Sites and Services, operational],...
# 39  [[Cloudflare Sites and Services, operational],...
# 40  [[Cloudflare Sites and Services, operational],...
# 41  [[Cloudflare Sites and Services, operational],...
# 42  [[Cloudflare Sites and Services, operational],...
# 43  [[Cloudflare Sites and Services, operational],...
# 44  [[Cloudflare Sites and Services, operational],...
# 45  [[Cloudflare Sites and Services, operational],...
# 46  [[Cloudflare Sites and Services, operational],...
# 47  [[Cloudflare Sites and Services, operational],...
# 48  [[Cloudflare Sites and Services, operational],...
# 49  [[Cloudflare Sites and Services, operational],...

# %%
df.to_csv(r'/home/shane/Documents/thesis/output/cloudflare-status.csv', index=False)

# %% [markdown]
# ### Blowup statuses

# %%
df2 = pd.read_csv('/home/shane/Documents/thesis/output/parsed/cloudflare-status.csv')
df2.head()
# Out:
#               source        service    timestamp_dir  \
# 0  cloudflare-status  global-status  20200508T150001
# 1  cloudflare-status  global-status  20200508T060001
# 2  cloudflare-status  global-status  20200508T130001
# 3  cloudflare-status  global-status  20200508T200001
# 4  cloudflare-status  global-status  20200508T030001
#
#                                               status
# 0  [['Cloudflare Sites and Services', 'operationa...
# 1  [['Cloudflare Sites and Services', 'operationa...
# 2  [['Cloudflare Sites and Services', 'operationa...
# 3  [['Cloudflare Sites and Services', 'operationa...
# 4  [['Cloudflare Sites and Services', 'operationa...

# %%
# Get names of the sub-services
status_types = set()
statuses = set()
for status in df2['status']:
    replaced = status.replace("], [","||").replace('[','').replace(']','').replace("', '", ',').replace("'", '')
    for part in replaced.split('||'):
        status_types.add(part.split(',')[0])
        statuses.add(part.split(',')[1])

# %%
statuses
# Out:
# {' AB',
#  ' AL',
#  ' AZ',
#  ' Angola - (LAD)',
#  ' Argentina - (EZE)',
#  ' Armenia - (EVN)',
#  ' Australia - (ADL)',
#  ' Austria - (VIE)',
#  ' Azerbaijan - (GYD)',
#  ' BC',
#  ' Bahrain - (BAH)',
#  ' Bangladesh - (CGP)',
#  ' Bangladesh - (DAC)',
#  ' Belgium - (BRU)',
#  ' Bhutan - (PBH)',
#  ' Brazil - (CWB)',
#  ' Brazil - (FOR)',
#  ' Brazil - (GIG)',
#  ' Brazil - (GRU)',
#  ' Brazil - (POA)',
#  ' Brunei - (BWN)',
#  ' Bulgaria - (SOF)',
#  ' CA',
#  ' CO',
#  ' Cambodia - (PNH)',
#  ' Chile - (ARI)',
#  ' Chile - (SCL)',
#  ' China - (CAN)',
#  ' China - (CGO)',
#  ' China - (CKG)',
#  ' China - (CSX)',
#  ' China - (CTU)',
#  ' China - (FOC)',
#  ' China - (FUO)',
#  ' China - (HGH)',
#  ' China - (HNY)',
#  ' China - (LYA)',
#  ' China - (NAY)',
#  ' China - (NBG)',
#  ' China - (NNG)',
#  ' China - (SHA)',
#  ' China - (SHE)',
#  ' China - (SJW)',
#  ' China - (SZV)',
#  ' China - (SZX)',
#  ' China - (TAO)',
#  ' China - (TNA)',
#  ' China - (TSN)',
#  ' China - (WUH)',
#  ' China - (WUX)',
#  ' China - (XIY)"',
#  ' Colombia - (BOG)',
#  ' Colombia - (MDE)',
#  ' Croatia - (ZAG)',
#  ' Curaçao - (CUR)',
#  ' Cyprus - (LCA)',
#  ' Czech Republic - (PRG)',
#  ' Denmark - (CPH)',
#  ' Djibouti - (JIB)',
#  ' Ecuador - (UIO)',
#  ' Egypt - (CAI)',
#  ' Estonia - (TLL)',
#  ' FL',
#  ' Finland - (HEL)',
#  ' France - (CDG)',
#  ' France - (MRS)',
#  ' France - (RUN)',
#  ' GA',
#  ' Germany - (DUS)',
#  ' Germany - (FRA)',
#  ' Germany - (HAM)',
#  ' Germany - (MUC)',
#  ' Germany - (TXL)',
#  ' Greece - (ATH)',
#  ' Greece - (SKG)',
#  ' Grenada - (GND)"',
#  ' Guatemala - (GUA)',
#  ' HI',
#  ' Haiti - (PAP)',
#  ' Honduras - (TGU)',
#  ' Hungary - (BUD)',
#  ' IL',
#  ' IN',
#  ' Iceland - (KEF)',
#  ' India - (BLR)',
#  ' India - (BOM)',
#  ' India - (CCU)',
#  ' India - (DEL)',
#  ' India - (HYD)',
#  ' India - (MAA)',
#  ' India - (NAG)',
#  ' Indonesia - (CGK)',
#  ' Iraq - (BGW)',
#  ' Ireland - (DUB)',
#  ' Ireland - (ORK)',
#  ' Israel - (TLV)',
#  ' Italy - (FCO)',
#  ' Italy - (MXP)',
#  ' Japan - (KIX)',
#  ' Japan - (NRT)',
#  ' Jordan - (AMM)',
#  ' Kenya - (MBA)',
#  ' Kuwait - (KWI)',
#  ' Laos - (VTE)',
#  ' Latvia - (RIX)',
#  ' Lebanon - (BEY)',
#  ' Liberia - (ROB)',
#  ' Lithuania - (VNO)',
#  ' Luxembourg - (LUX)',
#  ' MA',
#  ' MB',
#  ' MI',
#  ' MN',
#  ' MO',
#  ' MX',
#  ' MZ - (MPM)',
#  ' Madagascar - (TNR)',
#  ' Malaysia - (JHB)',
#  ' Malaysia - (KUL)',
#  ' Maldives - (MLE)',
#  ' Mauritius - (MRU)',
#  ' Mexico - (MEX)',
#  ' Moldova - (KIV)',
#  ' Mongolia - (ULN)',
#  ' Morocco - (CMN)',
#  ' NC',
#  ' NE',
#  ' NJ',
#  ' NSW',
#  ' NV',
#  ' NY',
#  ' Nepal - (KTM)',
#  ' Netherlands - (AMS)',
#  ' New Zealand - (AKL)',
#  ' New caledonia - (NOU)',
#  ' Nigeria - (LOS)',
#  ' Norway - (OSL)',
#  ' OH',
#  ' ON',
#  ' OR',
#  ' Oman - (MCT)',
#  ' PA',
#  ' Pakistan (ISB)',
#  ' Pakistan (KHI)',
#  ' Pakistan - (ISB)',
#  ' Pakistan - (KHI)',
#  ' Pakistan - (LHE)',
#  ' Panama - (PTY)',
#  ' Paraguay - (ASU)',
#  ' Peru - (LIM)',
#  ' Philippines - (CEB)',
#  ' Philippines - (MNL)',
#  ' Poland - (WAW)',
#  ' Portugal - (LIS)',
#  ' QC',
#  ' QLD',
#  ' Qatar - (DOH)',
#  ' Romania - (OTP)',
#  ' Russia - (DME)',
#  ' Russia - (LED)',
#  ' Rwanda - (KGL)',
#  ' SA',
#  ' SK',
#  ' Saudi Arabia - (RUH)',
#  ' Senegal - (DKR)',
#  ' Serbia - (BEG)',
#  ' Singapore - (SIN)',
#  ' South Africa - (CPT)',
#  ' South Africa - (DUR)',
#  ' South Africa - (JNB)',
#  ' South Korea - (ICN)',
#  ' Spain - (BCN)',
#  ' Spain - (MAD)',
#  ' Sri Lanka - (CMB)',
#  ' Suriname (pbm01)',
#  ' Suriname - (PBM)',
#  ' Sweden - (ARN)',
#  ' Sweden - (GOT)',
#  ' Switzerland - (GVA)',
#  ' Switzerland - (ZRH)',
#  ' TN',
#  ' TX',
#  ' Tanzania - (DAR)',
#  ' Thailand - (BKK)',
#  ' Turkey - (IST)',
#  ' UT',
#  ' Ukraine - (KBP)',
#  ' United Arab Emirates - (DXB)',
#  ' United Kingdom - (EDI)',
#  ' United Kingdom - (LHR)',
#  ' United Kingdom - (MAN)',
#  ' United States - (PHL)',
#  ' VA',
#  ' VIC',
#  ' Vietnam - (HAN)',
#  ' Vietnam - (SGN)',
#  ' Virginia - (RIC)',
#  ' WA',
#  ' operational',
#  'degraded_performance',
#  'major_outage',
#  'operational',
#  'partial_outage',
#  'under_maintenance'}

# %%
len(status_types) # new columns
# Out:
# 248

# %%
replaced = []
for status in df2['status']:
    replaced.append(status.replace("], [","||").replace('[','').replace(']','').replace("', '", ',').replace("'", ''))
replaced[0]
# Out:
# 'Cloudflare Sites and Services,operational||Cloudflare Dashboard,operational||Cloudflare Teams Dashboard,operational||Cloudflare Marketing Site,operational||"Cloudflare Developers Site", operational||Cloudflare API,operational||Cloudflare Registrar,operational||Cloudflare Workers,operational||Cloudflare Storage,operational||Cloudflare Access,operational||Cloudflare Spectrum,operational||Cloudflare Stream,operational||Cloudflare Logs,operational||Argo Tunnel,operational||Argo Smart Routing,operational||Analytics,operational||Billing,operational||CDN/Cache,operational||CDN Cache Purge,operational||SSL Certificate Provisioning,operational||SSL for SaaS Provisioning,operational||Geo-Key Manager,operational||Image Resizing,operational||Load Balancing and Monitoring,operational||Cloudflare Recursive DNS,operational||Cloudflare Authoritative DNS,operational||DNS Root Servers,operational||DNS Updates,operational||Always Online,operational||WARP,operational||Africa,partial_outage||Antananarivo, Madagascar - (TNR),operational||Cape Town, South Africa - (CPT),operational||Casablanca, Morocco - (CMN),operational||Dar Es Salaam, Tanzania - (DAR),operational||Djibouti City, Djibouti - (JIB),operational||Durban, South Africa - (DUR),partial_outage||Johannesburg, South Africa - (JNB),operational||Kigali, Rwanda - (KGL),operational||Lagos, Nigeria - (LOS),operational||Luanda, Angola - (LAD),operational||Maputo, MZ - (MPM),operational||Mombasa, Kenya - (MBA),operational||Monrovia, Liberia - (ROB),operational||Port Louis, Mauritius - (MRU),operational||Réunion, France - (RUN),operational||Asia,partial_outage||Bangalore, India - (BLR),operational||Bangkok, Thailand - (BKK),operational||Bandar Seri Begawan, Brunei - (BWN),partial_outage||Cebu, Philippines - (CEB),operational||Chengdu, China - (CTU),operational||Chennai, India - (MAA),operational||Chittagong, Bangladesh - (CGP),operational||Chongqing, China - (CKG),degraded_performance||Colombo, Sri Lanka - (CMB),operational||Dhaka, Bangladesh - (DAC),operational||Dongguan, China - (SZX),operational||Foshan, China - (FUO),operational||Fuzhou, China - (FOC),operational||Guangzhou, China - (CAN),degraded_performance||Hangzhou, China - (HGH),operational||Hanoi, Vietnam - (HAN),operational||Hengyang, China - (HNY),operational||Ho Chi Minh City, Vietnam - (SGN),operational||Hong Kong - (HKG),operational||Hyderabad, India - (HYD),operational||Islamabad, Pakistan - (ISB),operational||Jakarta, Indonesia - (CGK),operational||Jinan, China - (TNA),degraded_performance||Johor Bahru, Malaysia - (JHB),operational||Karachi, Pakistan - (KHI),partial_outage||Kathmandu, Nepal - (KTM),operational||Kolkata, India - (CCU),operational||Kuala Lumpur, Malaysia - (KUL),operational||Lahore, Pakistan - (LHE),partial_outage||Langfang, China - (NAY),operational||Luoyang, China - (LYA),operational||Macau - (MFM),operational||Malé, Maldives - (MLE),operational||Manila, Philippines - (MNL),operational||Mumbai, India - (BOM),operational||Nagpur, India - (NAG),operational||Nanning, China - (NNG),operational||New Delhi, India - (DEL),operational||Osaka, Japan - (KIX),operational||Phnom Penh, Cambodia - (PNH),operational||Qingdao, China - (TAO),operational||Seoul, South Korea - (ICN),operational||Shanghai, China - (SHA),operational||Shenyang, China - (SHE),degraded_performance||Shijiazhuang, China - (SJW),degraded_performance||Singapore, Singapore - (SIN),operational||Suzhou, China - (SZV),operational||Taipei - (TPE),operational||Thimphu, Bhutan - (PBH),partial_outage||Tianjin, China - (TSN),degraded_performance||Tokyo, Japan - (NRT),operational||Ulaanbaatar, Mongolia - (ULN),operational||Vientiane, Laos - (VTE),operational||Wuhan, China - (WUH),degraded_performance||Wuxi, China - (WUX),operational||"Xian, China - (XIY)", operational||Yerevan, Armenia - (EVN),operational||Zhengzhou, China - (CGO),degraded_performance||Zuzhou, China - (CSX),operational||Europe,operational||Amsterdam, Netherlands - (AMS),operational||Athens, Greece - ( ...

# %%
df3 = pd.DataFrame(replaced)
df3.columns = ['status']
df3.head()
# Out:
#                                               status
# 0  Cloudflare Sites and Services,operational||Clo...
# 1  Cloudflare Sites and Services,operational||Clo...
# 2  Cloudflare Sites and Services,operational||Clo...
# 3  Cloudflare Sites and Services,operational||Clo...
# 4  Cloudflare Sites and Services,operational||Clo...

# %%
# New dataframe for the statuses
df_status = pd.DataFrame(columns=status_types)
df_status.head()
# Out:
# Empty DataFrame
# Columns: [Durban, Mombasa, Enterprise Log Share (ELS), Cloudflare Stream, Richmond, Cloudflare Teams Dashboard, Düsseldorf, Hong Kong - (HKG), WARP, Jacksonville, Salt Lake City, Sofia, Chicago, Vientiane, Islamabad, Marseille, Seattle, Osaka, Singapore, Johor Bahru, Mexico City, Minneapolis, Argo Tunnel, Shanghai, São Paulo, Montgomery, Phoenix, Detroit, Hengyang, Billing, Denver, Hangzhou, Africa, Los Angeles, Hyderabad, Cape Town, Dallas, DNS Updates, Maputo, Cloudflare Dashboard, Las Vegas, Noumea, Seoul, Memphis, Baku, Cloudflare Spectrum, Tegucigalpa, CDN/Cache, "Xian, Kathmandu, Manila, Dhaka, Zuzhou, Milan, Muscat, Kansas City, Barcelona, Warsaw, Karachi, Cloudflare Authoritative DNS, Cloudflare Sites and Services, Chengdu, Analytics, Paramaribo, Montréal, Tallinn, Shenyang, Tel Aviv, Newark, Lagos, Cloudflare Logs, Vilnius, Ashburn, Middle East, Vancouver, Wuxi, Istanbul, Kuwait City, Charlotte, St. Louis, Panama City, Buffalo, Luanda, Zürich, Ulaanbaatar, Brisbane, Manchester, Zagreb, Fortaleza, Suzhou, Langfang, Rome, Sydney, Medellín, Kolkata, Omaha, Chittagong, Dublin, San Jose, Munich, ...]
# Index: []
#
# [0 rows x 248 columns]

# %%
# This is a bit ugly
for row, part in enumerate(df3['status']):
    for d in part.split('||'):
        d2 = d.split(',')
        df_status.at[row, d2[0]] = d2[-1]
    if row % 1000 == 0:
        print(row)
