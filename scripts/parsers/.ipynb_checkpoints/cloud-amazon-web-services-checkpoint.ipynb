# %%
import time
import glob as glob
from zipfile import ZipFile
from bs4 import BeautifulSoup
import dateutil.parser as dparser
from datetime import datetime
import pandas as pd
import multiprocessing as mp
import numpy as np
import io

# %%
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloud-amazon-web-services' # one directory
# root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloud-amazon-web-services/2020/20206' #subset of above
root_dir = '/media/shane/cloud-availability-sacheen-2020-05-11/cloud-amazon-web-services*' # all directories

# %%
def extract_html_data(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    result = []
    regions = []
    
    for block in soup.find_all('div', {'class':'pad8 whitebg bordered'}):
        regions.append(block['id'])
    
    try:
        for num, status in enumerate(soup.find_all('td', {'colspan': '3', 'class':'bb top pad8'})):
            if 'No recent events' in ' '.join(status.text.split()):
                result.append([regions[num], 0])
            else:
                result.append([regions[num], ' '.join(status.text.split())])
    except:
        result.append('?')

    return [result]

# %%
def read_file(file):
    source = file.split('/')[4]
    archive = ZipFile(file, 'r')
    namelist = archive.namelist()
    ret = []
    for item in namelist:
        if 'html' in item and 'json' not in item:
            html = archive.read(item)
            service = item.split('/')[1].split('.')[0]
            ts = item.split('/')[0]
            data = extract_html_data(html)
            data.insert(0, ts)
            data.insert(0, service)
            data.insert(0, source)
            ret.append(data)
    archive.close()
    return(ret)

# %%
files = glob.glob(root_dir + '/**/*.zip', recursive=True)
pool = mp.Pool(mp.cpu_count())
start_time = time.time()
try:
    results = pool.map(read_file, [file for file in files])
except:
    print('Error')
pool.close()
end_time = time.time()

# %%
print(end_time - start_time)
# Out:
# 91.92383122444153

# %%
res = []
for outer in results:
    for inner in outer:
        res.append(inner)
print(len(res))
# Out:
# 240

# %%
column_names = ['source','service','timestamp','status']
df = pd.DataFrame(res, columns=column_names)
df.head(50)
# Out:
#                        source        service        timestamp  \
# 0   cloud-amazon-web-services  global-status  20200602T050001
# 1   cloud-amazon-web-services  global-status  20200602T150001
# 2   cloud-amazon-web-services  global-status  20200602T090002
# 3   cloud-amazon-web-services  global-status  20200602T020001
# 4   cloud-amazon-web-services  global-status  20200602T080001
# 5   cloud-amazon-web-services  global-status  20200602T070001
# 6   cloud-amazon-web-services  global-status  20200602T040001
# 7   cloud-amazon-web-services  global-status  20200602T160001
# 8   cloud-amazon-web-services  global-status  20200602T190001
# 9   cloud-amazon-web-services  global-status  20200602T220001
# 10  cloud-amazon-web-services  global-status  20200602T200002
# 11  cloud-amazon-web-services  global-status  20200602T000001
# 12  cloud-amazon-web-services  global-status  20200602T170001
# 13  cloud-amazon-web-services  global-status  20200602T110001
# 14  cloud-amazon-web-services  global-status  20200602T060001
# 15  cloud-amazon-web-services  global-status  20200602T120001
# 16  cloud-amazon-web-services  global-status  20200602T100001
# 17  cloud-amazon-web-services  global-status  20200602T230001
# 18  cloud-amazon-web-services  global-status  20200602T010001
# 19  cloud-amazon-web-services  global-status  20200602T130001
# 20  cloud-amazon-web-services  global-status  20200602T030001
# 21  cloud-amazon-web-services  global-status  20200602T180001
# 22  cloud-amazon-web-services  global-status  20200602T210001
# 23  cloud-amazon-web-services  global-status  20200602T140002
# 24  cloud-amazon-web-services  global-status  20200603T080002
# 25  cloud-amazon-web-services  global-status  20200603T230002
# 26  cloud-amazon-web-services  global-status  20200603T010001
# 27  cloud-amazon-web-services  global-status  20200603T160001
# 28  cloud-amazon-web-services  global-status  20200603T150001
# 29  cloud-amazon-web-services  global-status  20200603T100001
# 30  cloud-amazon-web-services  global-status  20200603T130001
# 31  cloud-amazon-web-services  global-status  20200603T190001
# 32  cloud-amazon-web-services  global-status  20200603T120001
# 33  cloud-amazon-web-services  global-status  20200603T090001
# 34  cloud-amazon-web-services  global-status  20200603T030001
# 35  cloud-amazon-web-services  global-status  20200603T110001
# 36  cloud-amazon-web-services  global-status  20200603T180001
# 37  cloud-amazon-web-services  global-status  20200603T140001
# 38  cloud-amazon-web-services  global-status  20200603T040001
# 39  cloud-amazon-web-services  global-status  20200603T020001
# 40  cloud-amazon-web-services  global-status  20200603T050001
# 41  cloud-amazon-web-services  global-status  20200603T170001
# 42  cloud-amazon-web-services  global-status  20200603T070001
# 43  cloud-amazon-web-services  global-status  20200603T060001
# 44  cloud-amazon-web-services  global-status  20200603T200001
# 45  cloud-amazon-web-services  global-status  20200603T220001
# 46  cloud-amazon-web-services  global-status  20200603T000001
# 47  cloud-amazon-web-services  global-status  20200603T210001
# 48  cloud-amazon-web-services  global-status  20200606T230001
# 49  cloud-amazon-web-services  global-status  20200606T090001
#
#                                                status
# 0   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 1   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 2   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 3   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 4   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 5   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 6   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 7   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 8   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 9   [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 10  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 11  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 12  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 13  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 14  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 15  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 16  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 17  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 18  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 19  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 20  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 21  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 22  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 23  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 24  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 25  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 26  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 27  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 28  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 29  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 30  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 31  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 32  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 33  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 34  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 35  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 36  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 37  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 38  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 39  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 40  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 41  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 42  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 43  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 44  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 45  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 46  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 47  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 48  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...
# 49  [[NA_block, 0], [SA_block, 0], [EU_block, 0], ...

# %%
# df.to_csv(r'/home/shane/Documents/thesis/output/cloud-amazon-web-services.csv', index=False)
